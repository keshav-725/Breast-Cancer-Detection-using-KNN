# %% [markdown]
# # Import Modules

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import confusion_matrix,accuracy_score

# %% [markdown]
# # Read Dataset from CSV file

# %%
wisc = pd.read_csv("d:/data/wisc_bc_data.csv")

# %%
wisc.shape
# Out:
# (569, 32)

# %%
wisc.columns
# Out:
# Index(['id', 'diagnosis', 'radius_mean', 'texture_mean', 'perimeter_mean',
#        'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean',
#        'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean',
#        'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
#        'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se',
#        'fractal_dimension_se', 'radius_worst', 'texture_worst',
#        'perimeter_worst', 'area_worst', 'smoothness_worst',
#        'compactness_worst', 'concavity_worst', 'concave points_worst',
#        'symmetry_worst', 'fractal_dimension_worst'],
#       dtype='object')

# %%
wisc.diagnosis.value_counts(normalize=True)
# Out:
# B    0.627417
# M    0.372583
# Name: diagnosis, dtype: float64

# %% [markdown]
# # Information about Data
#
# B : Benign -> Non-cancer
#
# M : Melignant -> Cancer

# %% [markdown]
# # Plotting of Data

# %%
figure,axes = plt.subplots(3,3,figsize=(15,15))
axes[0,0].plot("radius_mean",marker="o",ls="",color="green",data=wisc[wisc.diagnosis=='B'])
axes[0,0].plot("radius_mean",marker="o",ls="",color="red",data=wisc[wisc.diagnosis=='M'])
axes[0,0].set_title("radius mean")

axes[0,1].plot("texture_mean",marker="o",ls="",color="green",data=wisc[wisc.diagnosis=='B'])
axes[0,1].plot("texture_mean",marker="o",ls="",color="red",data=wisc[wisc.diagnosis=='M'])
axes[0,1].set_title("texture_mean")

axes[0,2].plot("perimeter_mean",marker="o",ls="",color="green",data=wisc[wisc.diagnosis=='B'])
axes[0,2].plot("perimeter_mean",marker="o",ls="",color="red",data=wisc[wisc.diagnosis=='M'])
axes[0,2].set_title("perimeter_mean")

axes[1,0].plot("smoothness_mean",marker="o",ls="",color="green",data=wisc[wisc.diagnosis=='B'])
axes[1,0].plot("smoothness_mean",marker="o",ls="",color="red",data=wisc[wisc.diagnosis=='M'])
axes[1,0].set_title("smoothness_mean")

axes[1,1].plot("compactness_mean",marker="o",ls="",color="green",data=wisc[wisc.diagnosis=='B'])
axes[1,1].plot("compactness_mean",marker="o",ls="",color="red",data=wisc[wisc.diagnosis=='M'])
axes[1,1].set_title("compactness_mean")

axes[1,2].plot("concavity_mean",marker="o",ls="",color="green",data=wisc[wisc.diagnosis=='B'])
axes[1,2].plot("concavity_mean",marker="o",ls="",color="red",data=wisc[wisc.diagnosis=='M'])
axes[1,2].set_title("concavity_mean")

axes[2,0].plot("concave points_mean",marker="o",ls="",color="green",data=wisc[wisc.diagnosis=='B'])
axes[2,0].plot("concave points_mean",marker="o",ls="",color="red",data=wisc[wisc.diagnosis=='M'])
axes[2,0].set_title("concave points_mean")

axes[2,1].plot("symmetry_mean",marker="o",ls="",color="green",data=wisc[wisc.diagnosis=='B'])
axes[2,1].plot("symmetry_mean",marker="o",ls="",color="red",data=wisc[wisc.diagnosis=='M'])
axes[2,1].set_title("symmetry_mean")

axes[2,2].plot("fractal_dimension_mean",marker="o",ls="",color="green",data=wisc[wisc.diagnosis=='B'])
axes[2,2].plot("fractal_dimension_mean",marker="o",ls="",color="red",data=wisc[wisc.diagnosis=='M'])
axes[2,2].set_title("fractal_dimension_mean")
plt.show()

# %%
figure,axes = plt.subplots(3,3,figsize=(15,15))
axes[0,0].plot("radius_worst",marker="o",ls="",color="green",data=wisc[wisc.diagnosis=='B'])
axes[0,0].plot("radius_worst",marker="o",ls="",color="red",data=wisc[wisc.diagnosis=='M'])
axes[0,0].set_title("radius worst")

axes[0,1].plot("texture_worst",marker="o",ls="",color="green",data=wisc[wisc.diagnosis=='B'])
axes[0,1].plot("texture_worst",marker="o",ls="",color="red",data=wisc[wisc.diagnosis=='M'])
axes[0,1].set_title("texture_worst")

axes[0,2].plot("perimeter_worst",marker="o",ls="",color="green",data=wisc[wisc.diagnosis=='B'])
axes[0,2].plot("perimeter_worst",marker="o",ls="",color="red",data=wisc[wisc.diagnosis=='M'])
axes[0,2].set_title("perimeter_worst")

axes[1,0].plot("smoothness_worst",marker="o",ls="",color="green",data=wisc[wisc.diagnosis=='B'])
axes[1,0].plot("smoothness_worst",marker="o",ls="",color="red",data=wisc[wisc.diagnosis=='M'])
axes[1,0].set_title("smoothness_worst")

axes[1,1].plot("compactness_worst",marker="o",ls="",color="green",data=wisc[wisc.diagnosis=='B'])
axes[1,1].plot("compactness_worst",marker="o",ls="",color="red",data=wisc[wisc.diagnosis=='M'])
axes[1,1].set_title("compactness_worst")

axes[1,2].plot("concavity_worst",marker="o",ls="",color="green",data=wisc[wisc.diagnosis=='B'])
axes[1,2].plot("concavity_worst",marker="o",ls="",color="red",data=wisc[wisc.diagnosis=='M'])
axes[1,2].set_title("concavity_worst")

axes[2,0].plot("concave points_worst",marker="o",ls="",color="green",data=wisc[wisc.diagnosis=='B'])
axes[2,0].plot("concave points_worst",marker="o",ls="",color="red",data=wisc[wisc.diagnosis=='M'])
axes[2,0].set_title("concave points_worst")

axes[2,1].plot("symmetry_worst",marker="o",ls="",color="green",data=wisc[wisc.diagnosis=='B'])
axes[2,1].plot("symmetry_worst",marker="o",ls="",color="red",data=wisc[wisc.diagnosis=='M'])
axes[2,1].set_title("symmetry_worst")

axes[2,2].plot("fractal_dimension_worst",marker="o",ls="",color="green",data=wisc[wisc.diagnosis=='B'])
axes[2,2].plot("fractal_dimension_worst",marker="o",ls="",color="red",data=wisc[wisc.diagnosis=='M'])
axes[2,2].set_title("fractal_dimension_worst")
plt.show()

# %% [markdown]
# # Data Preparation

# %%
X = wisc.iloc[:,[22,28]]
Y = wisc.iloc[:,1]
X.columns
# Out:
# Index(['radius_worst', 'concavity_worst'], dtype='object')

# %%
Y
# Out:
# 0      M
# 1      M
# 2      M
# 3      M
# 4      M
#       ..
# 564    M
# 565    M
# 566    M
# 567    M
# 568    B
# Name: diagnosis, Length: 569, dtype: object

# %%
X.describe()
# Out:
#        radius_worst  concavity_worst
# count    569.000000       569.000000
# mean      16.269190         0.272188
# std        4.833242         0.208624
# min        7.930000         0.000000
# 25%       13.010000         0.114500
# 50%       14.970000         0.226700
# 75%       18.790000         0.382900
# max       36.040000         1.252000

# %% [markdown]
# # Scaling Data using MinMaxScaler
#
# we are using KNN and all data are of different scale so we have to use MinMaxScaler to bring data on same scale.

# %%
minmaxscalar = MinMaxScaler()
pd.DataFrame(minmaxscalar.fit_transform(X),columns=X.columns)
# Out:
#      radius_worst  concavity_worst
# 0        0.620776         0.568610
# 1        0.606901         0.192971
# 2        0.556386         0.359744
# 3        0.248310         0.548642
# 4        0.519744         0.319489
# ..            ...              ...
# 564      0.623266         0.328035
# 565      0.560655         0.256789
# 566      0.393099         0.271805
# 567      0.633582         0.749760
# 568      0.054287         0.000000
#
# [569 rows x 2 columns]

# %%
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.25,stratify=Y)
print(Y_train.value_counts(normalize=True))
print(Y_test.value_counts(normalize=True))
# Out:
# B    0.626761
# M    0.373239
# Name: diagnosis, dtype: float64
# B    0.629371
# M    0.370629
# Name: diagnosis, dtype: float64

# %%
clf=KNeighborsClassifier()
clf.fit(X_train,Y_train)
Y_predict = clf.predict(X_test)
print("accuracy :",accuracy_score(Y_test,Y_predict))
confusion_matrix(Y_test,Y_predict)
# Out:
# accuracy : 0.9440559440559441
# array([[87,  3],
#        [ 5, 48]], dtype=int64)
